# %%
import math
class Circle:
  def __init__(self,r):
    self.__radius=r
  def setRadius(self,r):
    self.__radius=r
  def getRadius(self):
    return self.__radius
  def area(self):
    a=math.pi*self.__radius**2
    return a
c1 = Circle(4)
print('First circle radius:' , c1.getRadius())
print('First circle area:' , c1.area())


c2 = Circle(5)
print('Second circle radius:' , c2.getRadius())
print('Second circle area:' , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
class Triangle:
  def __init__(self, b,h):
    self.__base=b
    self.__height=h
  def setBase(self, b):
    self.__base=b
  def setHeight(self,h):
    self.__height=h
  def getBase(self):
    return self.__base
  def getHeight(self):
    return self.__height
  def area(self):
    a=0.5*self.__base*self.__height
    return a
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
class Teacher:
  def __init__(self,n,s):
    self.__name=n
    self.__sub=s
    self.__list=[]
  def addCourse(self,c):
    self.__list.append(c.course)
  def printDetail(self):
    print(f'====================================\n'
          f'Name: {self.__name}\n'
          f'Department: {self.__sub}\n'
          f'List of courses\n'
          f'====================================')
    for i in self.__list:
      print(i)
    print('====================================')

class Course:
  def __init__(self,course):
    self.course=course


t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi","CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithm")
c5 = Course("CSE 230 Discrete Mathematic")
c6 = Course("CSE 310 Object Oriented Programming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department: CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department: CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithm
# CSE 230 Discrete Mathematic
# ...
# Name: Sadia Kazi
# Department: CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
class Team:
  def __init__(self, team="Bangladesh"):
    self.__team=Team
    self.__plylst=[]

  def setName(self, team):
    self.__team=Team
  def addPlayer(self,player):
    self.__plylst.append(player.name)

  def printDetail(self):
    print(f'=====================\n'
           f'Team:{ Team}\n'
           f'List of Player:\n'
           f'{self.__plylst}\n'
           f'=====================')


class Player:
  def __init__(self,name):
    self.name=name


b = Team()
b.setName('Bangladesh')
mashrafi = Player('Mashrafi')
b.addPlayer(mashrafi)
tamim = Player('Tamim')
b.addPlayer(tamim)
b.printDetail()
a = Team('Australia')
ponting = Player('Ponting')
a.addPlayer(ponting)
lee = Player('Lee')
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team:<class '__main__.Team'>
# List of Player:
# ['Mashrafi', 'Tamim']
# ...
# Team:<class '__main__.Team'>
# List of Player:
# ['Ponting', 'Lee']
# ...

# %%
class Student:
  def __init__(self,name,id,dept,email= None, password=None,status=None):
    self.name=name
    self.id=id
    self.dept=dept
    self.email=email
    self.password=password
    self.status=status
    self.sublst=[]
    print("Student object is created!")






class Usis:
  def __init__(self):
    print("USIS is ready to use!")
    self.loginde=0
  def login (self,name):
    if name.email==None and name.password==None:
      print("Please login to advise courses!")
    else:
      print("Login successful!")
      self.loginde+=1
  def advising(self,name,*subs):
    if self.loginde==0:
      print("Please login to advise courses!")
    elif self.loginde==1:
      if len(subs)==0:
        print("You haven't selected any courses.")
      elif len(subs)>3:
        print("You need special approval to take more than 3 courses.")
      else:
        print("Advising successful!")
        for i in subs:
          name.sublst.append(i)


  def individualDetails(self,name):
    print(f'Name: {name.name}\n'
          f'ID: {name.id}\n'
          f'Department: {name.dept}\n'
          f'Advised coursres:{name.sublst}')



rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Please login to advise courses!
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name: Rakib
# ID: 12301455
# Department: CSE
# Advised coursres:['CSE110', 'PHY111', 'MAT110']
# None

# %%
class Train:
  def __init__(self,train,*args):
    self.args=args
    self.passlst=[]
    print(f'Welcome aboard on {train}\n'
          f'Start: {args[0]}\n'
          f'Destination: {args[-1]}')

  def addPassenger(self, *pass):
    for i in pass:
      print(f'{i} welcome aboard')
      self.passlst.append(i)
      if len(i.)



class Passenger:
  def __init__(self,name,*stops):
    self.name=name
    self.stops=stops

# %%
class BracuStudent:
  def __init__(self,name, home,buspass=None):

    self.name=name
    self.home=home
    self.buspass=buspass
  def show_details(self):
    print( f'Student Name: {self.name}\n'
           f'Lives in {self.home}\n')
    if self.buspass== None:
      print(f'Have Bus pass? False')
    else:
      print(f'Have Bus Pass? True')
  def get_pass(self):
    self.buspass= 'true'

class BracuBus:
  def __init__(self,area,count=2):
    self.area= area
    self.count=count
    self.passlst=[]

  def board(self,*arg):
    if len(arg)==0:
      print("No passenger!")
    else:
      for i in arg:
        if len(arg)<=self.count:
          if i.buspass== 'true':
            if i.home==self.area:
              print(f'{i.name} boarded the bus')
              self.passlst.append(i.name)
            else:
              print("You got on wrong bus!")
          else:
            print("You don't have bus pass!")
        else:
          print("Bus is full!")

  def show_details(self):
    print(f'Bus Route: {self.area}\n'
          f'Passengers On Board: {self.passlst}')

st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
#
# Have Bus pass? False
# Student Name: Shanto
# Lives in Motijheel
#
# Have Bus pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
#
# Have Bus pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers On Board: []
# 4===========================
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
#
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
#
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student Name: Afif
# Lives in Mirpur
#
# Have Bus Pass? True
# Student Name: Shanto
# Lives in Mirpur
#
# Have Bus Pass? True
# 9===========================
# Bus is full!
# Bus is full!
# Bus is full!
# 10===========================
# Bus Route: Mirpur
# ...

# %%
class BracuStudent:
  def __init__(self,name, home,buspass=None):

    self.name=name
    self.home=home
    self.buspass=buspass
  def show_details(self):
    print( f'Student Name: {self.name}\n'
           f'Lives in {self.home}\n')
    if self.buspass== None:
      print(f'Have Bus pass? False')
    else:
      print(f'Have Bus Pass? True')
  def get_pass(self):
    self.buspass= 'true'

class BracuBus:
  def __init__(self,area,count=2):
    self.area= area
    self.count=count
    self.passlst=[]

  def board(self,*arg):

    if len(arg)!=0:
      for i in arg:
        if i.home==self.area:
          if i.buspass=='true':
            if len (arg)<self.count:
              print(f'{i.name} boarded the bus')
              self.passlst.append(i.name)
            else:
              print("Bus is full!")
          else:
            print("You don't have bus pass!")
        else:
          print("You got on wrong bus!")
    else:
      print(" no passengers")



  def show_details(self):
    print(f'Bus Route: {self.area}\n'
          f'Passengers On Board: {self.passlst}')

st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
#
# Have Bus pass? False
# Student Name: Shanto
# Lives in Motijheel
#
# Have Bus pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
#
# Have Bus pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers On Board: []
# 4===========================
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
#
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
#
# Have Bus Pass? True
# 6===========================
#  no passengers
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student Name: Afif
# Lives in Mirpur
#
# Have Bus Pass? True
# Student Name: Shanto
# Lives in Mirpur
#
# Have Bus Pass? True
# 9===========================
# Bus is full!
# Bus is full!
# Bus is full!
# 10===========================
# Bus Route: Mirpur
# ...

# %%
class Library:
  def __init__(self,lab,books):
    self.lab=lab
    self.books=books
    self.borrower={}

  def details(self):
    print(f'{self.lab} Library details\n'
          f'Borrower details: {self.borrower}\n'
          f'Books availability: {self.books}')
class Reader:
  def __init__(self,name):
    self.name=name
    self.count=0

  def borrow(self,lab,*multi):
    for i in multi:
      for m in lab.books:
